# %% [markdown]
# - Dữ liệu gốc gồm khoảng 12k trang PDF về việc sao kê tài khoản [xem tại đây](https://www.facebook.com/thongtinchinhphu/posts/959216112909836?rdid=EPKEC1ZRp6J9MTI1)
# - Dữ liệu sau khi được xử lí và chia sẻ tại nhóm [AIO Question / Answer and Competition](https://github.com/dauvannam1804/DonationLookupBot/tree/main/data)

# %%
# Tải dữ liệu
# !wget https://raw.githubusercontent.com/dauvannam1804/DonationLookupBot/main/data/transactions.csv
# Out:
# --2024-09-14 02:16:07--  https://raw.githubusercontent.com/dauvannam1804/DonationLookupBot/main/data/transactions.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29109969 (28M) [text/plain]
# Saving to: ‘transactions.csv’
#
# transactions.csv    100%[===================>]  27.76M   128MB/s    in 0.2s
#
# 2024-09-14 02:16:08 (128 MB/s) - ‘transactions.csv’ saved [29109969/29109969]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/transactions.csv")

# %% [markdown]
# **Date:** Ngày giao dịch <br>
# **Amount:** Số tiền giao dịch <br>
# **Content:** Nội dung chuyển khoảng <br>
# **CT Code:** Mã số chứng thực

# %%
df.head(5)
# Out:
#          Date  Amount                                            Content  \
# 0  01/09/2024   50000                                                NaN
# 1  01/09/2024   20000  VCB.CTDK.31/03/2024.ADIDA PHAT. CT tu 04810007...
# 2  01/09/2024   29000  MBVCB.6916176124.CAO VIET TUAN chuyen tien.CT ...
# 3  01/09/2024    3000        272986.010924.101858.DO DUC LOI chuyen tien
# 4  01/09/2024    3000  020097040509011046122024JDC5013867.96713 .1046...
#
#       CT Code
# 0  5213.45946
# 1  5090.85797
# 2  5241.83107
# 3  5218.87149
# 4  5388.96713

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200364 entries, 0 to 200363
# Data columns (total 4 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   Date     200364 non-null  object
#  1   Amount   200364 non-null  int64
#  2   Content  194545 non-null  object
#  3   CT Code  200364 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 6.1+ MB

# %%
df.describe()
# Out:
#              Amount
# count  2.003640e+05
# mean   6.741839e+05
# std    4.697396e+06
# min    1.000000e+03
# 25%    1.000000e+05
# 50%    2.000000e+05
# 75%    5.000000e+05
# max    1.000000e+09

# %%
df['Amount'].nunique()
# Out:
# 3628

# %%
df.Amount.value_counts().head(20)
# Out:
# Amount
# 100000      43602
# 200000      43021
# 500000      32081
# 1000000     19626
# 50000       14857
# 300000      12808
# 2000000      4861
# 20000        2996
# 10000        2752
# 5000000      2256
# 150000       1859
# 30000        1418
# 3000000      1263
# 400000       1179
# 10000000     1169
# 250000        598
# 5000          496
# 1500000       461
# 40000         409
# 2000          391
# Name: count, dtype: int64

# %% [markdown]
# **Số lượng giao dịch trong từng ngày từ 01/09/2024 đến 11/09/2024**

# %%
# Chuyển cột "Date" sang kiểu datetime
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)

# %%
df['Date'].head()
# Out:
# 0   2024-09-01
# 1   2024-09-01
# 2   2024-09-01
# 3   2024-09-01
# 4   2024-09-01
# Name: Date, dtype: datetime64[ns]

# %%
# Đếm số lượng giao dịch theo từng ngày
daily_transactions = df.groupby(df['Date'].dt.date).size()

# Vẽ biểu đồ đường
plt.figure(figsize=(10, 6))
plt.plot(daily_transactions.index, daily_transactions.values, marker='o', linestyle='-', color='b')

# Thêm số vào các cột mốc
for i, value in enumerate(daily_transactions.values):
    plt.annotate(f'{value}', (daily_transactions.index[i], daily_transactions.values[i]),
                 textcoords="offset points", xytext=(0, 5), ha='center')

# Thêm tiêu đề và nhãn
plt.title('Số lượng giao dịch theo từng ngày')
plt.xlabel('Ngày')
plt.ylabel('Số lượng giao dịch')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

# Hiển thị biểu đồ
plt.show()

# %%
# Vẽ biểu đồ phân tán
plt.figure(figsize=(10, 6))
sns.boxplot(x='Date', y='Amount', data=df)
plt.title('Phân phối số tiền giao dịch theo ngày')
plt.xlabel('Ngày giao dịch')
plt.ylabel('Số tiền giao dịch (tỷ đồng)')
plt.xticks(rotation=45)
plt.grid(False)
plt.show()

# %% [markdown]
# - Giao dịch có giá trị cao nhất xảy ra vào ngày 10/09, với giá trị gần 1 tỷ đồng.
# - Có sự tăng đột biến về số lượng và giá trị giao dịch trong 3 ngày cuối (08/09, 09/09, 10/09).

# %% [markdown]
# **Phân tích nội dung chuyển khoản (Content)**

# %%
from wordcloud import WordCloud

# %%
# Kết hợp tất cả các nội dung thành một chuỗi văn bản
text = ' '.join(df['Content'].astype(str))

# Tạo đối tượng WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='viridis').generate(text)

# Hiển thị biểu đồ WordCloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Tắt hiển thị trục
plt.show()

# %% [markdown]
# - **Từ khóa nổi bật nhất:**
# "ung", "ho", "dong", "bao": Đây là từ lớn nhất, chiếm vị trí trung tâm, liên quan đến việc ủng hộ đồng bào bị ảnh hưởng bởi bão lũ
#
# - **Nhóm từ liên quan đến ngân hàng và tài chính:**
# "CT" (có thể là chuyển tiền, chứng thực), "chuyen tien", "Swift", "Vietcombank", "BFTV", "VCB", "Telex", "TRO" (có thể là trợ lý)
# "Quoc te" (quốc tế), "toi" (tới), "tu" (từ), "dong bao" (đồng bào)
#
# - **Tên địa danh và khu vực:**
# "HANOI", "mien Bac" (miền Bắc), "AVENUE", "KHAI AVENUE"
#
# - **Tên người hoặc phần của tên:**
# "NGUYEN", "THI", "TW" (có thể là Trung ương)
#
# - **Các từ khác:**
# "Yagi": Tên của cơn bão gây thiệt hại,
# "VN": Viết tắt của Việt Nam

# %%
import nltk
from nltk.util import ngrams
from collections import Counter

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# Tokenize văn bản thành các từ
words = nltk.word_tokenize(text)

# %%
# Tạo bigram và trigram
bigrams = list(ngrams(words, 2))
trigrams = list(ngrams(words, 3))
four_grams = list(ngrams(words, 4))
five_grams = list(ngrams(words, 5))

# Đếm tần suất của các bigram và trigram
bigram_freq = Counter(bigrams)
trigram_freq = Counter(trigrams)
four_gram_freq = Counter(four_grams)
five_gram_freq = Counter(five_grams)

# %%
# Chuyển đổi n-grams thành chuỗi văn bản và tạo DataFrame
def ngram_to_df(ngram_freq, n):
    # Chuyển đổi n-grams thành chuỗi văn bản
    ngram_strings = [' '.join(ngram) for ngram in ngram_freq.keys()]
    # Tạo DataFrame
    df = pd.DataFrame(list(ngram_freq.items()), columns=['n_gram', 'count'])
    return df.sort_values(by='count', ascending=False)

# Tạo các DataFrame cho bigram, trigram, 4-gram và 5-gram
df_bigram = ngram_to_df(bigram_freq, 2)
df_trigram = ngram_to_df(trigram_freq, 3)
df_fourgram = ngram_to_df(four_gram_freq, 4)
df_fivegram = ngram_to_df(five_gram_freq, 5)

# %% [markdown]
# Các n-gram theo thứ tự giảm dần

# %%
df_bigram.head(20)
# Out:
#                     n_gram  count
# 201              (ung, ho)  54225
# 205            (dong, bao)  52474
# 16              (CUU, TRO)  42819
# 11              (TO, QUOC)  42357
# 10              (TRAN, TO)  42336
# 9              (MAT, TRAN)  42326
# 15              (BAN, CUU)  42308
# 17               (TRO, TW)  42303
# 12              (QUOC, VN)  42286
# 13                 (VN, -)  41948
# 14                (-, BAN)  41942
# 7     (toi, 0011001932418)  41107
# 32          (chuyen, tien)  41084
# 8     (0011001932418, MAT)  40745
# 204             (ho, dong)  38897
# 996           (khac, phuc)  23522
# 967              (bao, lu)  22168
# 968              (lu, lut)  15854
# 1612           (tien, ung)  13999
# 1001             (bao, so)  13773

# %%
df_trigram.head(20)
# Out:
#                           n_gram  count
# 10              (TRAN, TO, QUOC)  42327
# 9                (MAT, TRAN, TO)  42325
# 15               (BAN, CUU, TRO)  42307
# 16                (CUU, TRO, TW)  42303
# 11                (TO, QUOC, VN)  42285
# 14                 (-, BAN, CUU)  41942
# 12                 (QUOC, VN, -)  41938
# 13                  (VN, -, BAN)  41937
# 7      (toi, 0011001932418, MAT)  40745
# 8     (0011001932418, MAT, TRAN)  40745
# 219              (ho, dong, bao)  38020
# 1188             (ung, ho, dong)  21676
# 2029             (tien, ung, ho)  13731
# 1222            (ho, khac, phuc)  13479
# 1228                (bao, so, 3)  12042
# 98           (TRAN, QUANG, KHAI)  12028
# 106              (HANOI, -, S.R)  12027
# 105             (VNVX, HANOI, -)  12027
# 104          (BFTV, VNVX, HANOI)  12027
# 103              (:, BFTV, VNVX)  12027

# %%
df_fourgram.head(20)
# Out:
#                                             n_gram  count
# 9                            (MAT, TRAN, TO, QUOC)  42321
# 15                             (BAN, CUU, TRO, TW)  42294
# 10                            (TRAN, TO, QUOC, VN)  42285
# 14                              (-, BAN, CUU, TRO)  41942
# 11                               (TO, QUOC, VN, -)  41938
# 13                               (VN, -, BAN, CUU)  41937
# 12                              (QUOC, VN, -, BAN)  41937
# 7                  (toi, 0011001932418, MAT, TRAN)  40745
# 8                   (0011001932418, MAT, TRAN, TO)  40745
# 1285                          (ung, ho, dong, bao)  21159
# 103                       (AVENUE, Swift, :, BFTV)  12027
# 102                       (KHAI, AVENUE, Swift, :)  12027
# 101                   (QUANG, KHAI, AVENUE, Swift)  12027
# 115   (www.vietcombank.com.vn, Contact, center, :)  12027
# 100                    (TRAN, QUANG, KHAI, AVENUE)  12027
# 99                        (198, TRAN, QUANG, KHAI)  12027
# 104                         (Swift, :, BFTV, VNVX)  12027
# 106                         (BFTV, VNVX, HANOI, -)  12027
# 107                          (VNVX, HANOI, -, S.R)  12027
# 108                             (HANOI, -, S.R, .)  12027

# %%
df_fivegram.head(20)
# Out:
#                                                 n_gram  count
# 9                            (MAT, TRAN, TO, QUOC, VN)  42282
# 14                              (-, BAN, CUU, TRO, TW)  41939
# 10                             (TRAN, TO, QUOC, VN, -)  41938
# 12                             (QUOC, VN, -, BAN, CUU)  41937
# 11                              (TO, QUOC, VN, -, BAN)  41937
# 13                              (VN, -, BAN, CUU, TRO)  41937
# 7                  (toi, 0011001932418, MAT, TRAN, TO)  40745
# 8                 (0011001932418, MAT, TRAN, TO, QUOC)  40745
# 108                           (VNVX, HANOI, -, S.R, .)  12027
# 116  (www.vietcombank.com.vn, Contact, center, :, 1...  12027
# 115    (:, www.vietcombank.com.vn, Contact, center, :)  12027
# 113  (VIETNAM, Website, :, www.vietcombank.com.vn, ...  12027
# 112   (., VIETNAM, Website, :, www.vietcombank.com.vn)  12027
# 111                      (S.R, ., VIETNAM, Website, :)  12027
# 110                      (-, S.R, ., VIETNAM, Website)  12027
# 109                        (HANOI, -, S.R, ., VIETNAM)  12027
# 114  (Website, :, www.vietcombank.com.vn, Contact, ...  12027
# 107                        (BFTV, VNVX, HANOI, -, S.R)  12027
# 102                    (QUANG, KHAI, AVENUE, Swift, :)  12027
# 106                          (:, BFTV, VNVX, HANOI, -)  12027

# %% [markdown]
# **Các n-gram theo thứ tự tăng dần**

# %% [markdown]
# bigram

# %%
df_bigram.tail(20)
# Out:
#                                                    n_gram  count
# 252484                 (483633.100924.141748.IBFT, HOANG)      1
# 252483                  (Yagi, 483633.100924.141748.IBFT)      1
# 252472                  (tien, 574167.100924.141743.PHAN)      1
# 252465                   (263175.100924.141749.DONG, GOP)      1
# 252466                          (3, YAGI-100924-14:17:47)      1
# 252467                     (YAGI-100924-14:17:47, 263175)      1
# 252468                 (263175, 428175.100924.141748.Ung)      1
# 252469                     (428175.100924.141748.Ung, ho)      1
# 252470                     (lu, 428187.100924.141748.NGO)      1
# 252471                   (428187.100924.141748.NGO, MINH)      1
# 252473                   (574167.100924.141743.PHAN, THI)      1
# 252482                           (Thanh-WindWin, Fanpage)      1
# 252474                   (Yagi, 265326.100924.141748.Ung)      1
# 252475                     (265326.100924.141748.Ung, ho)      1
# 252476     (lu, 020097041509101417482024VkEo213214.15914)      1
# 252477  (020097041509101417482024VkEo213214.15914, .14...      1
# 252478                         (.141749.NCT-WAYV, WINWIN)      1
# 252479                                     (WINWIN, Dong)      1
# 252481                                (Tu, Thanh-WindWin)      1
# 707952                     (807439.100924.223851.cua, it)      1

# %%
df_bigram[df_bigram['count']>=100].tail(50)
# Out:
#                 n_gram  count
# 9803        (vi, dong)    103
# 22152       (VU, NGOC)    103
# 2286      (NGOC, DUNG)    103
# 1998     (NGUYEN, MAI)    103
# 12898        (lu, sau)    103
# 47541        (an, nan)    103
# 3442       (NGOC, NHU)    103
# 6070    (chong, thien)    103
# 5087         (va, cac)    103
# 2248       (THANH, TU)    103
# 27561    (KIM, PHUONG)    102
# 30409      (tinh, anh)    102
# 14210        (., MONG)    102
# 10960      (THU, NGAN)    102
# 14525   (NGUYEN, THAO)    102
# 37879      (BAC, VUOT)    102
# 7808       (deu, duoc)    102
# 7425        (VAN, DUC)    102
# 11024        (My, ung)    102
# 7932      (KHANH, ung)    102
# 3107     (nhieu, tien)    102
# 11674     (MANH, HUNG)    102
# 43412        (LUT, VA)    102
# 6857       (TUAN, ung)    102
# 12208    (HOANG, NGOC)    101
# 15041     (QUOC, VIET)    101
# 5108       (VIET, toi)    101
# 11194      (OANH, ung)    101
# 24961    (TRA, chuyen)    101
# 13418        (se, den)    101
# 1420        (KIM, YEN)    101
# 5826         (yagi, ,)    101
# 1083           (:, DO)    101
# 8358    (NGAN, Chuyen)    101
# 11820      (THI, TINH)    101
# 6856         (LE, ANH)    101
# 13612      (cac, dong)    101
# 15716  (CHINH, chuyen)    101
# 10499      (gop, giup)    100
# 12507        (ho, dan)    100
# 6367       (Thuy, ung)    100
# 29393    (Nguyen, Thi)    100
# 1034    (PHAT, chuyen)    100
# 3052          (ca, si)    100
# 27054       (THI, LAM)    100
# 23850       (LOC, toi)    100
# 1737        (CHU, THI)    100
# 17850         (Y, toi)    100
# 15381        (it, cho)    100
# 1580    (THOA, chuyen)    100

# %%
df_bigram[df_bigram['count']>=1000].tail(50)
# Out:
#                  n_gram  count
# 1546          (3, yagi)   1447
# 2893        (con, mien)   1446
# 3524        (MIEN, BAC)   1433
# 755         (THI, MINH)   1432
# 619        (TRANG, toi)   1426
# 1251         (se, cung)   1420
# 3802          (gay, ra)   1403
# 233        (quyen, gop)   1373
# 5640       (Bac.CT, tu)   1370
# 1485         (QUA, BAO)   1354
# 346         (PHAM, THI)   1324
# 213    (PHUONG, chuyen)   1315
# 1231       (thanh, pho)   1292
# 9260       (THIET, HAI)   1282
# 600        (THI, HUYEN)   1251
# 1527        (NGOC, ANH)   1244
# 3317       (huong, boi)   1238
# 8416          (se, voi)   1235
# 23485     (tinh, thanh)   1234
# 266      (THAO, chuyen)   1233
# 8417        (voi, dong)   1233
# 1627         (ANH, ung)   1222
# 406        (THI, HUONG)   1211
# 1709        (PHUC, BAO)   1207
# 688      (PHUONG, THAO)   1200
# 1756           (ng, ho)   1187
# 1445          (tat, ca)   1186
# 1681         (giup, do)   1146
# 318        (THUY, LINH)   1138
# 3220        (dong, gop)   1122
# 5188    (CHUYEN, KHOAN)   1118
# 1027          (TW, nan)   1115
# 741         (THI, BICH)   1107
# 2182         (qua, con)   1100
# 2825         (lu, mien)   1096
# 772       (PHUONG, toi)   1094
# 4481       (bac.CT, tu)   1093
# 407     (HUONG, chuyen)   1089
# 1465          (tro, ba)   1085
# 24388         (pho, bi)   1064
# 3318         (boi, bao)   1058
# 14285    (dong, bao.CT)   1057
# 999          (bao, sau)   1054
# 5098          (LU, LUT)   1048
# 2844     (THUY, chuyen)   1043
# 4480     (mien, bac.CT)   1028
# 2264        (nhan, dan)   1017
# 962      (NGOC, chuyen)   1012
# 2240        (chiu, anh)   1007
# 1552          (3, YAGI)   1002

# %% [markdown]
# trigram

# %%
df_trigram.tail(20)
# Out:
#                                                     n_gram  count
# 380398                                     (-, Nguoi, ham)      1
# 380400                           (Yagi.CT, tu, 9815999909)      1
# 380401                            (tu, 9815999909, NGUYEN)      1
# 380402                          (9815999909, NGUYEN, BICH)      1
# 380403                                (NGUYEN, BICH, DUNG)      1
# 380406   (TRO, TW, 020097041509101419052024ot8l215801.1...      1
# 380419                               (.CT, tu, 1039655070)      1
# 380407   (TW, 020097041509101419052024ot8l215801.19468....      1
# 380408   (020097041509101419052024ot8l215801.19468.1, 4...      1
# 380409                            (41905.Thai, Hoang, ung)      1
# 380410                     (lu, lut, MBVCB.6992768292.ung)      1
# 380411                     (lut, MBVCB.6992768292.ung, ho)      1
# 380412                   (MBVCB.6992768292.ung, ho, thiet)      1
# 380413                           (3.CT, tu, 0381000441708)      1
# 380414                         (tu, 0381000441708, NGUYEN)      1
# 380415                        (0381000441708, NGUYEN, THI)      1
# 380416                    (TRO, TW, MBVCB.6992768391.PHAN)      1
# 380417                    (TW, MBVCB.6992768391.PHAN, THI)      1
# 380418                    (MBVCB.6992768391.PHAN, THI, MY)      1
# 1065393               (807439.100924.223851.cua, it, long)      1

# %%
df_trigram[df_trigram['count']>=100].tail(50)
# Out:
#                            n_gram  count
# 35329            (THI, NGOC, LAN)    103
# 70977             (bao, lu, Mien)    103
# 48136                (bao, ,, lu)    103
# 70119             (binh, an, nan)    103
# 58770               (Bac, bi, lu)    103
# 35153            (long, nho, den)    103
# 58883      (HOA, chuyen, tien.CT)    103
# 32047               (HO, BAO, LU)    103
# 7234               (Hoa, ung, ho)    103
# 646             (THI, LAN, HUONG)    103
# 18388       (chuyen, tien, chung)    102
# 6450             (THU, HANG, toi)    102
# 53992            (MINH, ANH, toi)    102
# 27518            (Cau, mong, moi)    102
# 13745           (THI, NHUNG, toi)    102
# 10944            (long, nho, gui)    102
# 22248        (DIEP, chuyen, tien)    102
# 13274               (HO, LU, LUT)    102
# 44373          (tinh, anh, huong)    102
# 3239          (CHUYEN, TIEN, UNG)    102
# 7009          (Duong, Story, ung)    102
# 300            (LE, chuyen, tien)    102
# 41874             (mien, Bac, lu)    102
# 11555        (NGAN, Chuyen, tien)    101
# 3040              (qua, sau, con)    101
# 10933            (KHANH, ung, ho)    101
# 7757             (MY, DUYEN, toi)    101
# 6927   (VIET, toi, 0011001932418)    101
# 63454          (tinh, bao, lu.CT)    101
# 11106          (NGUYEN, THI, MAI)    101
# 40319       (TRUNG, HIEU, chuyen)    101
# 2473               (SAU, BAO, SO)    101
# 8379          (KHANH, LY, chuyen)    101
# 11387           (chuyen, tien, .)    101
# 15441               (My, ung, ho)    101
# 24746               (xin, gop, 1)    101
# 8156               (TRA, MY, toi)    101
# 42001              (3, YAGI, GAY)    101
# 11846         (HUONG, GIANG, toi)    101
# 25999         (bi, thien, tai.CT)    101
# 5547             (Bao, Mien, Bac)    101
# 44372            (cac, tinh, anh)    101
# 13587              (lu, lut, cac)    100
# 9969        (phuc, thien, tai.CT)    100
# 11894          (bao, bao, lut.CT)    100
# 25524     (Y, toi, 0011001932418)    100
# 30680        (chuyen, khoan, ung)    100
# 45411            (THI, KIM, THOA)    100
# 34493   (LOC, toi, 0011001932418)    100
# 15657            (dong, bao, kho)    100

# %%
df_trigram[df_trigram['count']>=1000].tail(50)
# Out:
#                              n_gram  count
# 1542             (dong, bao, thiet)   1535
# 1923                (bao, so, 3.CT)   1527
# 12662                (hai, do, con)   1516
# 993            (LINH, chuyen, tien)   1506
# 1844                (UNG, HO, KHAC)   1497
# 1879               (phuc, sau, bao)   1493
# 1847               (PHUC, HAU, QUA)   1488
# 1846              (KHAC, PHUC, HAU)   1484
# 1782              (dong, bao, vuot)   1477
# 1287                (ung, ho, mien)   1468
# 7235               (cuu, tro, dong)   1448
# 1937                  (so, 3, yagi)   1436
# 750     (TRANG, toi, 0011001932418)   1426
# 5448               (som, vuot, qua)   1420
# 3224              (phuc, bao, yagi)   1376
# 3819                (ba, con, mien)   1361
# 842                 (do, bao, yagi)   1335
# 2127                (qua, sau, bao)   1314
# 1411                 (qua, bao, lu)   1310
# 2317            (chuyen, tien, cuu)   1308
# 4005               (bao, vuot, qua)   1302
# 386          (chuyen, tien, Postal)   1294
# 1527                 (bao, bao, lu)   1281
# 10995               (vung, lu, lut)   1244
# 4403              (anh, huong, boi)   1236
# 3061             (chuyen, tien, ho)   1232
# 11642              (voi, dong, bao)   1213
# 2050                 (ANH, ung, ho)   1212
# 2223                (ho, mien, bac)   1210
# 1848                (HAU, QUA, BAO)   1196
# 2165              (KHAC, PHUC, BAO)   1193
# 33951            (cac, tinh, thanh)   1174
# 439           (TRANG, chuyen, tien)   1172
# 5308                (phuc, bao, lu)   1154
# 2279               (qua, bao, yagi)   1137
# 13157             (bao, lu, lut.CT)   1123
# 1731               (sau, bao, yagi)   1122
# 1262                 (TRO, TW, nan)   1115
# 11435             (tinh, bi, thiet)   1103
# 6774               (dan, vung, bao)   1100
# 942    (PHUONG, toi, 0011001932418)   1094
# 1827                 (tro, ba, con)   1071
# 1540               (se, cung, dong)   1067
# 20222            (dong, bao.CT, tu)   1057
# 35313              (thanh, pho, bi)   1041
# 8174               (dong, bao, sau)   1039
# 6062             (mien, bac.CT, tu)   1028
# 3231                (Ung, ho, dong)   1020
# 11641               (se, voi, dong)   1016
# 2899             (chiu, anh, huong)   1002

# %% [markdown]
# fourgram

# %%
df_fourgram.tail(20)
# Out:
#                                                     n_gram  count
# 494165        (bac, 175775.100924.141852.Chung, tay, chia)      1
# 494183    (232229.100924.141852.QUACH, NGOC, TRAM, Chuyen)      1
# 494175   (chuyen, tien, 02009704150910141853202447PZ215...      1
# 494182       (bao, 232229.100924.141852.QUACH, NGOC, TRAM)      1
# 494181       (dong, bao, 232229.100924.141852.QUACH, NGOC)      1
# 494180         (ho, dong, bao, 232229.100924.141852.QUACH)      1
# 494179                       (141853.HA, THI, THU, Chuyen)      1
# 494178                            (., 141853.HA, THI, THU)      1
# 494177   (02009704150910141853202447PZ215536.19207, ., ...      1
# 494176   (tien, 02009704150910141853202447PZ215536.1920...      1
# 494174   (Thien, chuyen, tien, 020097041509101418532024...      1
# 494166         (175775.100924.141852.Chung, tay, chia, se)      1
# 494173                          (Nam, Thien, chuyen, tien)      1
# 494172   (687087.100924.141852.Nguyen, Nam, Thien, chuyen)      1
# 494171     (2024, 687087.100924.141852.Nguyen, Nam, Thien)      1
# 494170       (tai, 2024, 687087.100924.141852.Nguyen, Nam)      1
# 494169     (thien, tai, 2024, 687087.100924.141852.Nguyen)      1
# 494168                            (phuc, thien, tai, 2024)      1
# 494167                                 (tay, chia, se, ho)      1
# 1390605        (807439.100924.223851.cua, it, long, nhieu)      1

# %%
df_fourgram[df_fourgram['count']>=100].tail(50)
# Out:
#                                     n_gram  count
# 57750                 (mong, ba, con, som)    104
# 10191           (HONG, NGOC, chuyen, tien)    104
# 20350         (GIANG, chuyen, tien.CT, tu)    104
# 27795              (chut, tam, long, mong)    104
# 74286           (HOA, chuyen, tien.CT, tu)    103
# 28212               (deu, binh, an.CT, tu)    103
# 10478           (THI, PHUONG, ANH, chuyen)    103
# 10999               (dong, bao, mien, nui)    103
# 11914               (chut, tam, long, cho)    103
# 35818                 (long, nho, ung, ho)    103
# 59538               (QUYNH, ung, ho, dong)    102
# 47359                  (Yagi, va, lu, lut)    102
# 71802               (huong, ve, dong, bao)    102
# 7531       (THU, HANG, toi, 0011001932418)    102
# 49295                 (HOA, ung, ho, dong)    102
# 16423     (THI, NHUNG, toi, 0011001932418)    102
# 67925      (MINH, ANH, toi, 0011001932418)    102
# 8180               (Duong, Story, ung, ho)    102
# 10807                (mien, Bac, binh, an)    102
# 31765              (bi, thien, tai.CT, tu)    101
# 55411              (cac, tinh, anh, huong)    101
# 51582                  (,, THANH, PHO, BI)    101
# 3650               (CHUYEN, TIEN, UNG, HO)    101
# 9089       (MY, DUYEN, toi, 0011001932418)    101
# 80182               (tinh, bao, lu.CT, tu)    101
# 8085       (VIET, toi, 0011001932418, MAT)    101
# 20463             (cuu, tro, bao, Yagi.CT)    101
# 9575         (TRA, MY, toi, 0011001932418)    101
# 14079   (HUONG, GIANG, toi, 0011001932418)    101
# 52318                   (SO, 3, YAGI, GAY)    101
# 3537                 (so, 3, Yagi, Postal)    101
# 8814            (THU, HUYEN, chuyen, tien)    101
# 3415                  (hau, qua, sau, con)    101
# 24741               (tro, dong, bao, vuot)    101
# 11825                 (THI, LAN, ANH, toi)    100
# 42642       (LOC, toi, 0011001932418, MAT)    100
# 9247              (qua, bao, Yagi, Postal)    100
# 93011                (vung, lu, phia, Bac)    100
# 26571            (THU, THUY, chuyen, tien)    100
# 165600               (bao, cac, tinh, bao)    100
# 27132                (bao, lut, mien, bac)    100
# 31157         (Y, toi, 0011001932418, MAT)    100
# 14138               (bao, bao, lut.CT, tu)    100
# 33694              (Cau, mong, moi, nguoi)    100
# 58559                (CUU, TRO, DONG, BAO)    100
# 103723               (cung, ba, con, vung)    100
# 3416                  (qua, sau, con, bao)    100
# 80181              (cac, tinh, bao, lu.CT)    100
# 11782            (phuc, thien, tai.CT, tu)    100
# 4565                   (qua, kho, khan, a)    100

# %%
df_fourgram[df_fourgram['count']>=1000].tail(50)
# Out:
#                                   n_gram  count
# 57211                (tinh, bi, bao, lu)   1691
# 2521             (khac, phuc, bao, Yagi)   1679
# 23447                (ba, con, vung, lu)   1677
# 2213               (tien, ung, ho, khac)   1671
# 1668                (hai, do, bao, Yagi)   1644
# 86            (tien, Postal, address, :)   1601
# 371      (LINH, toi, 0011001932418, MAT)   1560
# 3290                  (hai, do, bao, so)   1555
# 19795                 (bao, bi, lu, lut)   1535
# 2090                 (bao, so, 3.CT, tu)   1527
# 1665             (dong, bao, thiet, hai)   1524
# 15081              (thiet, hai, do, con)   1512
# 15082                (hai, do, con, bao)   1508
# 2326               (phuc, hau, qua, sau)   1496
# 2001              (KHAC, PHUC, HAU, QUA)   1472
# 2038              (khac, phuc, sau, bao)   1472
# 1999               (UNG, HO, KHAC, PHUC)   1470
# 804     (TRANG, toi, 0011001932418, MAT)   1426
# 2107                  (bao, so, 3, yagi)   1398
# 1964              (ho, dong, bao, thiet)   1389
# 8451               (cuu, tro, dong, bao)   1389
# 3632             (khac, phuc, bao, yagi)   1360
# 2854              (bao, khac, phuc, hau)   1351
# 9350              (ho, nguoi, dan, vung)   1337
# 6634               (bi, anh, huong, bao)   1334
# 15587                 (ung, ho, lu, lut)   1322
# 15157                 (do, con, bao, so)   1320
# 2327                (hau, qua, sau, bao)   1309
# 403      (chuyen, tien, Postal, address)   1294
# 4562              (dong, bao, vuot, qua)   1281
# 2247            (mong, moi, nguoi, binh)   1276
# 1649                (dong, bao, bao, lu)   1273
# 3441             (chuyen, tien, ho, tro)   1217
# 2697                (tien, ung, ho, bao)   1183
# 2557            (chuyen, tien, cuu, tro)   1172
# 2002               (PHUC, HAU, QUA, BAO)   1170
# 4220                  (ung, ho, bao, lu)   1152
# 6131               (khac, phuc, bao, lu)   1145
# 15697              (bao, lu, lut.CT, tu)   1123
# 1366                 (CUU, TRO, TW, nan)   1115
# 1015   (PHUONG, toi, 0011001932418, MAT)   1094
# 13575             (cac, tinh, bi, thiet)   1089
# 13576             (tinh, bi, thiet, hai)   1073
# 15696            (dong, bao, lu, lut.CT)   1072
# 1666               (bao, thiet, hai, do)   1051
# 1663               (se, cung, dong, bao)   1035
# 2000               (HO, KHAC, PHUC, HAU)   1027
# 10439              (bi, anh, huong, boi)   1008
# 3640                (Ung, ho, dong, bao)   1007
# 13826               (se, voi, dong, bao)   1004

# %% [markdown]
# fivegram

# %%
df_fivegram.tail(20)
# Out:
#                                                     n_gram  count
# 587797              (1015267263, HOANG, THI, THANH, HUYEN)      1
# 587796                 (tu, 1015267263, HOANG, THI, THANH)      1
# 587795                 (lu.CT, tu, 1015267263, HOANG, THI)      1
# 587794                 (bao, lu.CT, tu, 1015267263, HOANG)      1
# 587793                    (co, bao, lu.CT, tu, 1015267263)      1
# 587792                            (su, co, bao, lu.CT, tu)      1
# 587791                          (phuc, su, co, bao, lu.CT)      1
# 587790      (MBVCB.6992765264.Hoang, Huyen, ung, ho, khac)      1
# 587788      (binh, an, MBVCB.6992765264.Hoang, Huyen, ung)      1
# 587774                  (60.141804.Ung, ho, ba, con, vung)      1
# 587787      (deu, binh, an, MBVCB.6992765264.Hoang, Huyen)      1
# 587786      (nguoi, deu, binh, an, MBVCB.6992765264.Hoang)      1
# 587784                             (bi, bao, lu, va, mong)      1
# 587780                           (van, anh, ung, ho, chia)      1
# 587779     (429125.100924.141824.Vuong, van, anh, ung, ho)      1
# 587778    (Bac, 429125.100924.141824.Vuong, van, anh, ung)      1
# 587777   (phia, Bac, 429125.100924.141824.Vuong, van, anh)      1
# 587776    (lu, phia, Bac, 429125.100924.141824.Vuong, van)      1
# 587775   (vung, lu, phia, Bac, 429125.100924.141824.Vuong)      1
# 1672850                        (nhieu, ung, ho, mien, bac)      1

# %%
df_fivegram[df_fivegram['count']>=100].tail(50)
# Out:
#                                          n_gram  count
# 8754                 (ho, cuu, tro, nguoi, dan)    104
# 17728                 (tro, dong, bao, bao, lu)    104
# 23693     (DIEP, toi, 0011001932418, MAT, TRAN)    104
# 2697       (TAI, toi, 0011001932418, MAT, TRAN)    104
# 13161             (chung, tay, cung, dong, bao)    104
# 77803                 (chia, se, cung, ba, con)    104
# 26462     (DIEU, LINH, toi, 0011001932418, MAT)    104
# 16874               (dong, bao, vuot, qua, con)    104
# 16513                (HO, DONG, BAO, VUOT, QUA)    103
# 2275                   (ho, cuu, tro, sau, bao)    103
# 108395                   (bao, bi, lu, lut, va)    103
# 169178              (CAC, TINH, BI, THIET, HAI)    103
# 5272                     (hai, con, bao, so, 3)    103
# 17359               (chuyen, tien, ho, tro, ba)    103
# 2022                 (ho, dong, bao, vuot, bao)    103
# 18409     (THI, NHUNG, toi, 0011001932418, MAT)    102
# 45822                  (ho, ba, con, dong, bao)    102
# 78252      (MINH, ANH, toi, 0011001932418, MAT)    102
# 8330       (THU, HANG, toi, 0011001932418, MAT)    102
# 482               (THI, VAN, ANH, chuyen, tien)    102
# 21426               (tro, dong, bao, cac, tinh)    101
# 49241                (ung, ho, mien, Bac, khac)    101
# 59892                   (BAO, SO, 3, YAGI, GAY)    101
# 5498              (THI, HAI, YEN, chuyen, tien)    101
# 88369              (tro, dong, bao, lu, lut.CT)    101
# 3703                (tien, ho, tro, nguoi, dan)    101
# 10638        (TRA, MY, toi, 0011001932418, MAT)    101
# 8948      (VIET, toi, 0011001932418, MAT, TRAN)    101
# 68381               (QUYNH, ung, ho, dong, bao)    101
# 46338                (bi, thiet, hai, boi, bao)    101
# 15749   (HUONG, GIANG, toi, 0011001932418, MAT)    101
# 23029              (cuu, tro, bao, Yagi.CT, tu)    101
# 3810             (so, 3, Yagi, Postal, address)    101
# 10086      (MY, DUYEN, toi, 0011001932418, MAT)    101
# 5023                (ca, nuoc, khac, phuc, hau)    101
# 22450                (dan, bi, anh, huong, boi)    101
# 59012                 (TINH, ,, THANH, PHO, BI)    101
# 7752             (chuyen, tien, cuu, tro, mien)    101
# 194049              (dong, bao, cac, tinh, bao)    100
# 21921             (nguoi, dan, khac, phuc, bao)    100
# 4963                  (vuot, qua, kho, khan, a)    100
# 15423             (THI, LAN, ANH, chuyen, tien)    100
# 55569                (tien, UNG, HO, DONG, BAO)    100
# 3674                  (hau, qua, sau, con, bao)    100
# 48593      (LOC, toi, 0011001932418, MAT, TRAN)    100
# 91680                (Ung, ho, dong, bao, mien)    100
# 35304        (Y, toi, 0011001932418, MAT, TRAN)    100
# 13185       (THI, LAN, ANH, toi, 0011001932418)    100
# 92643               (cac, tinh, bao, lu.CT, tu)    100
# 10264         (qua, bao, Yagi, Postal, address)    100

# %%
df_fivegram[df_fivegram['count']>=1000].tail(50)
# Out:
#                                         n_gram  count
# 2981               (ho, dong, bao, khac, phuc)   2391
# 7915                 (bao, bi, thiet, hai, do)   2380
# 1542      (ANH, toi, 0011001932418, MAT, TRAN)   2193
# 3731                (ung, ho, dong, bao, mien)   2134
# 2208                 (phuc, hau, qua, bao, so)   2042
# 65624                 (ho, cac, tinh, bi, bao)   2009
# 2432               (phuc, hau, qua, bao, Yagi)   1943
# 1903               (dong, bao, bi, anh, huong)   1923
# 2209                    (hau, qua, bao, so, 3)   1903
# 12919               (ho, dong, bao, mien, Bac)   1739
# 65625                 (cac, tinh, bi, bao, lu)   1682
# 2330               (tien, ung, ho, khac, phuc)   1643
# 1745               (thiet, hai, do, bao, Yagi)   1641
# 47765                (ung, ho, dong, bao, cac)   1601
# 87           (tien, Postal, address, :, Telex)   1601
# 383      (LINH, toi, 0011001932418, MAT, TRAN)   1560
# 3534                 (thiet, hai, do, bao, so)   1548
# 3732                (ho, dong, bao, mien, bac)   1547
# 22276                 (dong, bao, bi, lu, lut)   1524
# 7305                  (ho, dong, bao, bi, anh)   1524
# 16897               (thiet, hai, do, con, bao)   1504
# 2456               (khac, phuc, hau, qua, sau)   1473
# 839     (TRANG, toi, 0011001932418, MAT, TRAN)   1426
# 3048                (ung, ho, dong, bao, khac)   1398
# 2056               (ho, dong, bao, thiet, hai)   1380
# 2851             (chuyen, tien, ung, ho, khac)   1372
# 3535                     (hai, do, bao, so, 3)   1347
# 3050               (bao, khac, phuc, hau, qua)   1340
# 3049              (dong, bao, khac, phuc, hau)   1338
# 14550                (ho, dong, bao, vung, lu)   1330
# 418         (chuyen, tien, Postal, address, :)   1294
# 2457                (phuc, hau, qua, sau, bao)   1269
# 16896                (bi, thiet, hai, do, con)   1209
# 14549               (ung, ho, dong, bao, vung)   1186
# 16982                    (do, con, bao, so, 3)   1180
# 15525                (ung, ho, dong, bao, bao)   1176
# 23449                 (ung, ho, ba, con, vung)   1164
# 2095               (KHAC, PHUC, HAU, QUA, BAO)   1158
# 1434                  (BAN, CUU, TRO, TW, nan)   1115
# 1062   (PHUONG, toi, 0011001932418, MAT, TRAN)   1094
# 2370              (mong, moi, nguoi, binh, an)   1091
# 35646                  (ho, dong, bao, bi, lu)   1086
# 16981                  (hai, do, con, bao, so)   1078
# 17594              (dong, bao, lu, lut.CT, tu)   1072
# 15172              (cac, tinh, bi, thiet, hai)   1061
# 1726                  (ho, dong, bao, bao, lu)   1054
# 1743               (dong, bao, thiet, hai, do)   1047
# 2672               (ho, khac, phuc, bao, Yagi)   1040
# 26410                  (ho, ba, con, vung, lu)   1038
# 2094                (HO, KHAC, PHUC, HAU, QUA)   1021
